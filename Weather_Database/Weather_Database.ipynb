# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 751

# %%
#Import the dependencies
import requests
# Import API key
import sys
sys.path.append('../')
from config import weather_api_key

# %%
# Build basic URL with API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.    ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through all of the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create an endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:  
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | felanitx
# Processing Record 3 of Set 1 | hasaki
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | touros
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | coquimbo
# Processing Record 9 of Set 1 | xinxiang
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | kizu
# City not found. Skipping...
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 1 | bilma
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | hambantota
# Processing Record 30 of Set 1 | chinhoyi
# Processing Record 31 of Set 1 | gat
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | provideniya
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | vadso
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | puerto escondido
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | ormara
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | westerland
# Processing Record 42 of Set 1 | mount pleasant
# Processing Record 43 of Set 1 | longyearbyen
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 1 | sorland
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | ihosy
# Processing Record 48 of Set 1 | beziers
# Processing Record 49 of Set 1 | kahului
# Processing Record 50 of Set 1 | artsyz
# Processing Record 1 of Set 2 | caravelas
# Processing Record 2 of Set 2 | mount isa
# Processing Record 3 of Set 2 | kandrian
# Processing Record 4 of Set 2 | surt
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | nabire
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | ilulissat
# Processing Record 11 of Set 2 | aswan
# Processing Record 12 of Set 2 | saint anthony
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | ulladulla
# Processing Record 15 of Set 2 | yarada
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | clyde river
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | noumea
# Processing Record 20 of Set 2 | mackenzie
# Processing Record 21 of Set 2 | changji
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | kalmunai
# Processing Record 25 of Set 2 | port lincoln
# Processing Record 26 of Set 2 | lexington
# Processing Record 27 of Set 2 | half moon bay
# Processing Record 28 of Set 2 | kuah
# Processing Record 29 of Set 2 | wembley
# Processing Record 30 of Set 2 | carmo do rio claro
# Processing Record 31 of Set 2 | priargunsk
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | flinders
# Processing Record 35 of Set 2 | katsuura
# Processing Record 36 of Set 2 | port hedland
# Processing Record 37 of Set 2 | vila franca do campo
# Processing Record 38 of Set 2 | langham
# Processing Record 39 of Set 2 | yongchang
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | plettenberg bay
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | gland
# Processing Record 44 of Set 2 | higuey
# City not found. Skipping...
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 2 | port blair
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | rolante
# Processing Record 50 of Set 2 | necochea
# Processing Record 1 of Set 3 | codrington
# Processing Record 2 of Set 3 | egvekinot
# Processing Record 3 of Set 3 | dingle
# Processing Record 4 of Set 3 | lubao
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | tarko-sale
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | gilgit
# Processing Record 9 of Set 3 | ahuimanu
# Processing Record 10 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | anchorage
# Processing Record 13 of Set 3 | talnakh
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | emerald
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | manikling
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | pisco
# Processing Record 22 of Set 3 | sfantu gheorghe
# Processing Record 23 of Set 3 | galveston
# Processing Record 24 of Set 3 | barrow
# Processing Record 25 of Set 3 | panjab
# Processing Record 26 of Set 3 | iranshahr
# Processing Record 27 of Set 3 | vestmannaeyjar
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 3 | karakol
# Processing Record 31 of Set 3 | san policarpo
# Processing Record 32 of Set 3 | kingman
# Processing Record 33 of Set 3 | dubova
# Processing Record 34 of Set 3 | srednekolymsk
# Processing Record 35 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 3 | lubawa
# Processing Record 37 of Set 3 | taoudenni
# Processing Record 38 of Set 3 | lavrentiya
# Processing Record 39 of Set 3 | aklavik
# Processing Record 40 of Set 3 | conde
# Processing Record 41 of Set 3 | hangal
# Processing Record 42 of Set 3 | fortuna
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | lasa
# Processing Record 45 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 3 | lingao
# Processing Record 47 of Set 3 | talladega
# Processing Record 48 of Set 3 | road town
# Processing Record 49 of Set 3 | bardiyah
# Processing Record 50 of Set 3 | the valley
# Processing Record 1 of Set 4 | yerbogachen
# Processing Record 2 of Set 4 | murdochville
# Processing Record 3 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 4 | paita
# Processing Record 7 of Set 4 | taiyuan
# Processing Record 8 of Set 4 | sept-iles
# Processing Record 9 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 4 | araouane
# Processing Record 11 of Set 4 | saint-pierre
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | umm kaddadah
# Processing Record 14 of Set 4 | waddan
# Processing Record 15 of Set 4 | fairbanks
# Processing Record 16 of Set 4 | verkhniy rohachyk
# Processing Record 17 of Set 4 | orotukan
# Processing Record 18 of Set 4 | tasiilaq
# Processing Record 19 of Set 4 | boqueirao
# Processing Record 20 of Set 4 | sao joaquim
# Processing Record 21 of Set 4 | nizhniy kuranakh
# Processing Record 22 of Set 4 | kloulklubed
# Processing Record 23 of Set 4 | kumluca
# Processing Record 24 of Set 4 | alofi
# Processing Record 25 of Set 4 | avera
# Processing Record 26 of Set 4 | inirida
# Processing Record 27 of Set 4 | filingue
# Processing Record 28 of Set 4 | heiligenhafen
# Processing Record 29 of Set 4 | rio grande
# Processing Record 30 of Set 4 | hovd
# Processing Record 31 of Set 4 | saint-philippe
# Processing Record 32 of Set 4 | kiruna
# Processing Record 33 of Set 4 | huarmey
# Processing Record 34 of Set 4 | pangnirtung
# Processing Record 35 of Set 4 | labuhan
# Processing Record 36 of Set 4 | najran
# Processing Record 37 of Set 4 | pilao arcado
# City not found. Skipping...
# Processing Record 38 of Set 4 | kasimov
# Processing Record 39 of Set 4 | kodiak
# Processing Record 40 of Set 4 | berdigestyakh
# Processing Record 41 of Set 4 | pallasovka
# Processing Record 42 of Set 4 | cidreira
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | khuzhir
# Processing Record 45 of Set 4 | lorengau
# Processing Record 46 of Set 4 | rossland
# Processing Record 47 of Set 4 | adrar
# Processing Record 48 of Set 4 | sur
# Processing Record 49 of Set 4 | esperance
# Processing Record 50 of Set 4 | guerrero negro
# Processing Record 1 of Set 5 | kasongo-lunda
# Processing Record 2 of Set 5 | mareeba
# Processing Record 3 of Set 5 | north platte
# Processing Record 4 of Set 5 | okhotsk
# Processing Record 5 of Set 5 | san juan
# Processing Record 6 of Set 5 | ankazoabo
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | tyler
# Processing Record 9 of Set 5 | arlit
# Processing Record 10 of Set 5 | havoysund
# Processing Record 11 of Set 5 | nanortalik
# Processing Record 12 of Set 5 | severo-kurilsk
# Processing Record 13 of Set 5 | poum
# Processing Record 14 of Set 5 | ati
# Processing Record 15 of Set 5 | hauge
# Processing Record 16 of Set 5 | emmaus
# Processing Record 17 of Set 5 | sidi ali
# Processing Record 18 of Set 5 | saint george
# Processing Record 19 of Set 5 | georgetown
# Processing Record 20 of Set 5 | lugovoy
# Processing Record 21 of Set 5 | antsohihy
# Processing Record 22 of Set 5 | lisakovsk
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | soria
# Processing Record 25 of Set 5 | aitape
# Processing Record 26 of Set 5 | khatanga
# Processing Record 27 of Set 5 | juybar
# Processing Record 28 of Set 5 | matara
# Processing Record 29 of Set 5 | sabha
# Processing Record 30 of Set 5 | rumoi
# Processing Record 31 of Set 5 | tiksi
# Processing Record 32 of Set 5 | saint-augustin
# Processing Record 33 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 5 | puqi
# Processing Record 36 of Set 5 | ambilobe
# Processing Record 37 of Set 5 | san carlos del zulia
# Processing Record 38 of Set 5 | loukhi
# Processing Record 39 of Set 5 | lafiagi
# Processing Record 40 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 5 | kuito
# Processing Record 42 of Set 5 | minot
# Processing Record 43 of Set 5 | krasnokamensk
# Processing Record 44 of Set 5 | shwebo
# Processing Record 45 of Set 5 | los llanos de aridane
# Processing Record 46 of Set 5 | quatre cocos
# Processing Record 47 of Set 5 | balod
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | haimen
# Processing Record 50 of Set 5 | tawnat
# City not found. Skipping...
# Processing Record 1 of Set 6 | anloga
# Processing Record 2 of Set 6 | julio de castilhos
# Processing Record 3 of Set 6 | kungurtug
# Processing Record 4 of Set 6 | fukue
# Processing Record 5 of Set 6 | mehnagar
# Processing Record 6 of Set 6 | yarmouth
# Processing Record 7 of Set 6 | mildura
# Processing Record 8 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 6 | elizabeth city
# Processing Record 10 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 6 | manbij
# Processing Record 12 of Set 6 | rayong
# Processing Record 13 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 6 | patnanungan
# Processing Record 15 of Set 6 | ajdabiya
# Processing Record 16 of Set 6 | lima
# Processing Record 17 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 6 | sarakhs
# Processing Record 19 of Set 6 | lindi
# Processing Record 20 of Set 6 | alice springs
# Processing Record 21 of Set 6 | gweta
# Processing Record 22 of Set 6 | ancud
# Processing Record 23 of Set 6 | puro
# Processing Record 24 of Set 6 | northam
# Processing Record 25 of Set 6 | chapais
# Processing Record 26 of Set 6 | kirakira
# Processing Record 27 of Set 6 | lysva
# Processing Record 28 of Set 6 | krasnyy chikoy
# Processing Record 29 of Set 6 | west bay
# Processing Record 30 of Set 6 | piacabucu
# Processing Record 31 of Set 6 | vao
# Processing Record 32 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 6 | kembe
# Processing Record 34 of Set 6 | dayong
# Processing Record 35 of Set 6 | vostok
# Processing Record 36 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 6 | klaksvik
# Processing Record 38 of Set 6 | palu
# Processing Record 39 of Set 6 | gacko
# Processing Record 40 of Set 6 | los amates
# Processing Record 41 of Set 6 | saint-georges
# Processing Record 42 of Set 6 | kavieng
# Processing Record 43 of Set 6 | camp verde
# Processing Record 44 of Set 6 | college
# Processing Record 45 of Set 6 | ponta delgada
# Processing Record 46 of Set 6 | nicoya
# Processing Record 47 of Set 6 | boa vista
# Processing Record 48 of Set 6 | arco
# Processing Record 49 of Set 6 | cockburn town
# Processing Record 50 of Set 6 | qaqortoq
# Processing Record 1 of Set 7 | mbanza-ngungu
# Processing Record 2 of Set 7 | camocim
# Processing Record 3 of Set 7 | moron
# Processing Record 4 of Set 7 | port hardy
# Processing Record 5 of Set 7 | saint stephen
# Processing Record 6 of Set 7 | quelimane
# Processing Record 7 of Set 7 | lebu
# Processing Record 8 of Set 7 | sobolevo
# Processing Record 9 of Set 7 | gigmoto
# Processing Record 10 of Set 7 | geraldton
# Processing Record 11 of Set 7 | fenoarivo atsinanana
# Processing Record 12 of Set 7 | kayerkan
# Processing Record 13 of Set 7 | gharo
# Processing Record 14 of Set 7 | el coyote
# Processing Record 15 of Set 7 | cedar city
# Processing Record 16 of Set 7 | nizwa
# Processing Record 17 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 7 | chake chake
# Processing Record 19 of Set 7 | palmares do sul
# Processing Record 20 of Set 7 | brigantine
# Processing Record 21 of Set 7 | san luis de palenque
# Processing Record 22 of Set 7 | balkanabat
# Processing Record 23 of Set 7 | haapiti
# Processing Record 24 of Set 7 | tabou
# Processing Record 25 of Set 7 | mattru
# Processing Record 26 of Set 7 | mbandaka
# Processing Record 27 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 7 | micheweni
# Processing Record 29 of Set 7 | namatanai
# Processing Record 30 of Set 7 | ringebu
# Processing Record 31 of Set 7 | acapulco
# Processing Record 32 of Set 7 | vuktyl
# Processing Record 33 of Set 7 | pevek
# Processing Record 34 of Set 7 | muroto
# Processing Record 35 of Set 7 | tete
# Processing Record 36 of Set 7 | yinchuan
# Processing Record 37 of Set 7 | boueni
# Processing Record 38 of Set 7 | yulara
# Processing Record 39 of Set 7 | boden
# Processing Record 40 of Set 7 | saldanha
# Processing Record 41 of Set 7 | xining
# Processing Record 42 of Set 7 | barstow
# Processing Record 43 of Set 7 | cambyreta
# City not found. Skipping...
# Processing Record 44 of Set 7 | jiwani
# Processing Record 45 of Set 7 | olinda
# Processing Record 46 of Set 7 | tsabong
# Processing Record 47 of Set 7 | hit
# Processing Record 48 of Set 7 | marienburg
# Processing Record 49 of Set 7 | bengkulu
# Processing Record 50 of Set 7 | lavumisa
# Processing Record 1 of Set 8 | constitucion
# Processing Record 2 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 8 | aasiaat
# Processing Record 4 of Set 8 | pozo colorado
# Processing Record 5 of Set 8 | itaituba
# Processing Record 6 of Set 8 | awbari
# Processing Record 7 of Set 8 | dauphin
# Processing Record 8 of Set 8 | cayenne
# Processing Record 9 of Set 8 | kruisfontein
# Processing Record 10 of Set 8 | atasu
# Processing Record 11 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 8 | margate
# Processing Record 13 of Set 8 | kamenka
# Processing Record 14 of Set 8 | sukumo
# Processing Record 15 of Set 8 | rey bouba
# Processing Record 16 of Set 8 | zarubino
# Processing Record 17 of Set 8 | faanui
# Processing Record 18 of Set 8 | ulaangom
# Processing Record 19 of Set 8 | rivne
# Processing Record 20 of Set 8 | porteirinha
# Processing Record 21 of Set 8 | morant bay
# Processing Record 22 of Set 8 | ozark
# Processing Record 23 of Set 8 | morondava
# Processing Record 24 of Set 8 | buala
# Processing Record 25 of Set 8 | iskateley
# Processing Record 26 of Set 8 | camacha
# Processing Record 27 of Set 8 | venezuela
# Processing Record 28 of Set 8 | tura
# Processing Record 29 of Set 8 | biharamulo
# Processing Record 30 of Set 8 | shetpe
# Processing Record 31 of Set 8 | isangel
# Processing Record 32 of Set 8 | rabo de peixe
# Processing Record 33 of Set 8 | gravelbourg
# Processing Record 34 of Set 8 | pudozh
# Processing Record 35 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 8 | sao joao da barra
# Processing Record 37 of Set 8 | sohatu
# Processing Record 38 of Set 8 | broome
# Processing Record 39 of Set 8 | tabas
# Processing Record 40 of Set 8 | shizukuishi
# Processing Record 41 of Set 8 | niono
# Processing Record 42 of Set 8 | nishihara
# Processing Record 43 of Set 8 | nicolas bravo
# Processing Record 44 of Set 8 | hirara
# Processing Record 45 of Set 8 | kutum
# Processing Record 46 of Set 8 | harper
# Processing Record 47 of Set 8 | sao filipe
# Processing Record 48 of Set 8 | dicabisagan
# Processing Record 49 of Set 8 | ardino
# Processing Record 50 of Set 8 | charters towers
# Processing Record 1 of Set 9 | dunedin
# Processing Record 2 of Set 9 | mangrol
# Processing Record 3 of Set 9 | vila velha
# Processing Record 4 of Set 9 | ostrovnoy
# Processing Record 5 of Set 9 | nivala
# Processing Record 6 of Set 9 | namibe
# Processing Record 7 of Set 9 | hantsport
# Processing Record 8 of Set 9 | denpasar
# Processing Record 9 of Set 9 | oistins
# Processing Record 10 of Set 9 | angoche
# Processing Record 11 of Set 9 | outjo
# Processing Record 12 of Set 9 | athens
# Processing Record 13 of Set 9 | palmer
# Processing Record 14 of Set 9 | lethem
# Processing Record 15 of Set 9 | wenatchee
# Processing Record 16 of Set 9 | nome
# Processing Record 17 of Set 9 | mahibadhoo
# Processing Record 18 of Set 9 | luan
# Processing Record 19 of Set 9 | pokhara
# Processing Record 20 of Set 9 | praya
# Processing Record 21 of Set 9 | fez
# Processing Record 22 of Set 9 | victoria point
# Processing Record 23 of Set 9 | ugoofaaru
# Processing Record 24 of Set 9 | sinnamary
# Processing Record 25 of Set 9 | belaya gora
# Processing Record 26 of Set 9 | muncar
# Processing Record 27 of Set 9 | westport
# Processing Record 28 of Set 9 | yumen
# Processing Record 29 of Set 9 | port augusta
# Processing Record 30 of Set 9 | asau
# Processing Record 31 of Set 9 | sibolga
# Processing Record 32 of Set 9 | saskylakh
# Processing Record 33 of Set 9 | koslan
# Processing Record 34 of Set 9 | iqaluit
# Processing Record 35 of Set 9 | tautira
# Processing Record 36 of Set 9 | manicore
# Processing Record 37 of Set 9 | wheeling
# Processing Record 38 of Set 9 | tahta
# Processing Record 39 of Set 9 | damavand
# Processing Record 40 of Set 9 | riyadh
# Processing Record 41 of Set 9 | seoul
# Processing Record 42 of Set 9 | ixtapa
# Processing Record 43 of Set 9 | amarpur
# Processing Record 44 of Set 9 | nazareno
# Processing Record 45 of Set 9 | kenitra
# Processing Record 46 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 9 | conceicao do araguaia
# Processing Record 48 of Set 9 | asadabad
# Processing Record 49 of Set 9 | makung
# City not found. Skipping...
# Processing Record 50 of Set 9 | nuuk
# Processing Record 1 of Set 10 | villazon
# Processing Record 2 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 3 of Set 10 | berbera
# Processing Record 4 of Set 10 | rjukan
# Processing Record 5 of Set 10 | elko
# Processing Record 6 of Set 10 | jiayuguan
# Processing Record 7 of Set 10 | whitehorse
# Processing Record 8 of Set 10 | sholapur
# Processing Record 9 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 10 | yichun
# Processing Record 11 of Set 10 | nelson bay
# Processing Record 12 of Set 10 | sokolo
# Processing Record 13 of Set 10 | nioro
# Processing Record 14 of Set 10 | cedartown
# Processing Record 15 of Set 10 | narsaq
# Processing Record 16 of Set 10 | port keats
# Processing Record 17 of Set 10 | majene
# Processing Record 18 of Set 10 | mataruska banja
# Processing Record 19 of Set 10 | kivsharivka
# Processing Record 20 of Set 10 | bumba
# Processing Record 21 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 22 of Set 10 | bolobo
# Processing Record 23 of Set 10 | tezu
# Processing Record 24 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 10 | koulikoro
# Processing Record 26 of Set 10 | san cristobal
# Processing Record 27 of Set 10 | lamu
# Processing Record 28 of Set 10 | talakan
# Processing Record 29 of Set 10 | teknaf
# Processing Record 30 of Set 10 | hami
# Processing Record 31 of Set 10 | yaan
# Processing Record 32 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 10 | grand gaube
# Processing Record 35 of Set 10 | mlandizi
# Processing Record 36 of Set 10 | dakar
# Processing Record 37 of Set 10 | erenhot
# Processing Record 38 of Set 10 | korla
# Processing Record 39 of Set 10 | plaeng yao
# Processing Record 40 of Set 10 | krasnoselkup
# Processing Record 41 of Set 10 | danielskuil
# Processing Record 42 of Set 10 | beloha
# Processing Record 43 of Set 10 | rawson
# Processing Record 44 of Set 10 | marfino
# Processing Record 45 of Set 10 | makakilo city
# Processing Record 46 of Set 10 | prince rupert
# Processing Record 47 of Set 10 | krasnoshchekovo
# Processing Record 48 of Set 10 | marsh harbour
# Processing Record 49 of Set 10 | airai
# Processing Record 50 of Set 10 | grindavik
# Processing Record 1 of Set 11 | bairiki
# Processing Record 2 of Set 11 | suntar
# Processing Record 3 of Set 11 | paamiut
# Processing Record 4 of Set 11 | kushima
# Processing Record 5 of Set 11 | marrakesh
# Processing Record 6 of Set 11 | suratgarh
# Processing Record 7 of Set 11 | roma
# Processing Record 8 of Set 11 | buraydah
# Processing Record 9 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 11 | dom pedrito
# Processing Record 11 of Set 11 | azanka
# Processing Record 12 of Set 11 | boddam
# Processing Record 13 of Set 11 | uvat
# Processing Record 14 of Set 11 | pimentel
# Processing Record 15 of Set 11 | chunskiy
# Processing Record 16 of Set 11 | skibotn
# Processing Record 17 of Set 11 | akyab
# Processing Record 18 of Set 11 | daru
# Processing Record 19 of Set 11 | cherskiy
# Processing Record 20 of Set 11 | sambava
# Processing Record 21 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 22 of Set 11 | santiago del estero
# Processing Record 23 of Set 11 | grimari
# City not found. Skipping...
# Processing Record 24 of Set 11 | fuxin
# Processing Record 25 of Set 11 | razole
# Processing Record 26 of Set 11 | goderich
# Processing Record 27 of Set 11 | brokopondo
# Processing Record 28 of Set 11 | lagoa
# Processing Record 29 of Set 11 | mercedes
# Processing Record 30 of Set 11 | suhbaatar
# Processing Record 31 of Set 11 | eucaliptus
# Processing Record 32 of Set 11 | raahe
# Processing Record 33 of Set 11 | brae
# Processing Record 34 of Set 11 | ketchikan
# Processing Record 35 of Set 11 | lishui
# Processing Record 36 of Set 11 | moose factory
# Processing Record 37 of Set 11 | muana
# Processing Record 38 of Set 11 | borama
# City not found. Skipping...
# Processing Record 39 of Set 11 | zhanakorgan
# Processing Record 40 of Set 11 | saint-joseph
# Processing Record 41 of Set 11 | dharchula
# Processing Record 42 of Set 11 | dzhebariki-khaya
# Processing Record 43 of Set 11 | balkhash
# Processing Record 44 of Set 11 | sovetskaya gavan
# Processing Record 45 of Set 11 | ahipara
# Processing Record 46 of Set 11 | haines junction
# Processing Record 47 of Set 11 | duku
# Processing Record 48 of Set 11 | ponnani
# Processing Record 49 of Set 11 | portland
# Processing Record 50 of Set 11 | damghan
# Processing Record 1 of Set 12 | kinsale
# Processing Record 2 of Set 12 | sinegorye
# Processing Record 3 of Set 12 | lyngseidet
# Processing Record 4 of Set 12 | bulgan
# Processing Record 5 of Set 12 | waipawa
# Processing Record 6 of Set 12 | slonim
# Processing Record 7 of Set 12 | tadine
# Processing Record 8 of Set 12 | pietermaritzburg
# Processing Record 9 of Set 12 | sterling
# Processing Record 10 of Set 12 | pirgos
# Processing Record 11 of Set 12 | zhangye
# Processing Record 12 of Set 12 | port macquarie
# Processing Record 13 of Set 12 | tuatapere
# Processing Record 14 of Set 12 | otofuke
# Processing Record 15 of Set 12 | bom jesus
# Processing Record 16 of Set 12 | ust-kuyga
# Processing Record 17 of Set 12 | smithers
# Processing Record 18 of Set 12 | botou
# Processing Record 19 of Set 12 | baruun-urt
# Processing Record 20 of Set 12 | hamilton
# Processing Record 21 of Set 12 | arman
# Processing Record 22 of Set 12 | zalesovo
# Processing Record 23 of Set 12 | nanakuli
# Processing Record 24 of Set 12 | torbat-e jam
# Processing Record 25 of Set 12 | oppdal
# Processing Record 26 of Set 12 | mweka
# Processing Record 27 of Set 12 | vyazemskiy
# Processing Record 28 of Set 12 | chilliwack
# Processing Record 29 of Set 12 | rocky mountain house
# Processing Record 30 of Set 12 | lata
# Processing Record 31 of Set 12 | fasa
# Processing Record 32 of Set 12 | coihaique
# Processing Record 33 of Set 12 | sao miguel do araguaia
# Processing Record 34 of Set 12 | ossora
# Processing Record 35 of Set 12 | laguna
# Processing Record 36 of Set 12 | baherden
# Processing Record 37 of Set 12 | boguchany
# Processing Record 38 of Set 12 | courtenay
# Processing Record 39 of Set 12 | amga
# Processing Record 40 of Set 12 | stamsund
# City not found. Skipping...
# Processing Record 41 of Set 12 | hervey bay
# Processing Record 42 of Set 12 | mazyr
# Processing Record 43 of Set 12 | kavaratti
# Processing Record 44 of Set 12 | lodja
# Processing Record 45 of Set 12 | altamont
# Processing Record 46 of Set 12 | kamenskiy
# Processing Record 47 of Set 12 | kamaishi
# Processing Record 48 of Set 12 | kathmandu
# Processing Record 49 of Set 12 | alice
# Processing Record 50 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 1 of Set 13 | pontianak
# Processing Record 2 of Set 13 | kasempa
# Processing Record 3 of Set 13 | bagdarin
# Processing Record 4 of Set 13 | methoni
# Processing Record 5 of Set 13 | pierre
# Processing Record 6 of Set 13 | komsomolskiy
# Processing Record 7 of Set 13 | rio bueno
# Processing Record 8 of Set 13 | kudahuvadhoo
# Processing Record 9 of Set 13 | enumclaw
# Processing Record 10 of Set 13 | salinopolis
# Processing Record 11 of Set 13 | arraial do cabo
# Processing Record 12 of Set 13 | luderitz
# Processing Record 13 of Set 13 | batemans bay
# Processing Record 14 of Set 13 | galesong
# Processing Record 15 of Set 13 | khandyga
# Processing Record 16 of Set 13 | yichang
# Processing Record 17 of Set 13 | pangai
# Processing Record 18 of Set 13 | machinga
# Processing Record 19 of Set 13 | ciudad bolivar
# Processing Record 20 of Set 13 | novyy urengoy
# Processing Record 21 of Set 13 | mecca
# Processing Record 22 of Set 13 | warwick
# Processing Record 23 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 13 | la rioja
# Processing Record 25 of Set 13 | teya
# Processing Record 26 of Set 13 | champerico
# Processing Record 27 of Set 13 | vung tau
# Processing Record 28 of Set 13 | zatoka
# Processing Record 29 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 13 | bastia
# Processing Record 31 of Set 13 | saint-francois
# Processing Record 32 of Set 13 | tinde
# Processing Record 33 of Set 13 | qandala
# Processing Record 34 of Set 13 | ballitoville
# Processing Record 35 of Set 13 | lachhmangarh
# Processing Record 36 of Set 13 | bourail
# Processing Record 37 of Set 13 | san quintin
# Processing Record 38 of Set 13 | kampong chhnang
# Processing Record 39 of Set 13 | harrison
# Processing Record 40 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 41 of Set 13 | vilyuysk
# Processing Record 42 of Set 13 | tsogni
# Processing Record 43 of Set 13 | bandarbeyla
# Processing Record 44 of Set 13 | turukhansk
# Processing Record 45 of Set 13 | burica
# City not found. Skipping...
# Processing Record 46 of Set 13 | sapa
# Processing Record 47 of Set 13 | cravo norte
# Processing Record 48 of Set 13 | podgornoye
# Processing Record 49 of Set 13 | wasilla
# Processing Record 50 of Set 13 | ustrzyki dolne
# Processing Record 1 of Set 14 | gorontalo
# Processing Record 2 of Set 14 | nizhneangarsk
# Processing Record 3 of Set 14 | baker city
# Processing Record 4 of Set 14 | barabai
# Processing Record 5 of Set 14 | olafsvik
# Processing Record 6 of Set 14 | jijiga
# Processing Record 7 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 8 of Set 14 | det udom
# Processing Record 9 of Set 14 | vardo
# Processing Record 10 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 14 | bundaberg
# Processing Record 12 of Set 14 | vestmanna
# Processing Record 13 of Set 14 | cortez
# Processing Record 14 of Set 14 | karasjok
# Processing Record 15 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 16 of Set 14 | berlevag
# Processing Record 17 of Set 14 | batsfjord
# Processing Record 18 of Set 14 | samarai
# Processing Record 19 of Set 14 | shingu
# Processing Record 20 of Set 14 | terrasini
# Processing Record 21 of Set 14 | rychvald
# Processing Record 22 of Set 14 | meulaboh
# Processing Record 23 of Set 14 | presque isle
# Processing Record 24 of Set 14 | costinesti
# Processing Record 25 of Set 14 | ushtobe
# Processing Record 26 of Set 14 | general roca
# Processing Record 27 of Set 14 | ayan
# Processing Record 28 of Set 14 | batagay
# Processing Record 29 of Set 14 | ferrol
# Processing Record 30 of Set 14 | parabel
# Processing Record 31 of Set 14 | namuac
# Processing Record 32 of Set 14 | khor
# Processing Record 33 of Set 14 | bonavista
# Processing Record 34 of Set 14 | bontang
# Processing Record 35 of Set 14 | beringovskiy
# Processing Record 36 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 14 | tolaga bay
# Processing Record 38 of Set 14 | nadym
# Processing Record 39 of Set 14 | venice
# Processing Record 40 of Set 14 | torres
# Processing Record 41 of Set 14 | kaseda
# Processing Record 42 of Set 14 | kulhudhuffushi
# Processing Record 43 of Set 14 | zemio
# Processing Record 44 of Set 14 | balotra
# Processing Record 45 of Set 14 | babu
# Processing Record 46 of Set 14 | cairns
# Processing Record 47 of Set 14 | dunmore town
# Processing Record 48 of Set 14 | capao bonito
# Processing Record 49 of Set 14 | emba
# Processing Record 50 of Set 14 | murray bridge
# Processing Record 1 of Set 15 | mezhova
# Processing Record 2 of Set 15 | cap malheureux
# Processing Record 3 of Set 15 | marawi
# Processing Record 4 of Set 15 | tilichiki
# Processing Record 5 of Set 15 | gotsu
# Processing Record 6 of Set 15 | bubaque
# Processing Record 7 of Set 15 | escanaba
# Processing Record 8 of Set 15 | basoko
# Processing Record 9 of Set 15 | buriti
# Processing Record 10 of Set 15 | muros
# Processing Record 11 of Set 15 | were ilu
# Processing Record 12 of Set 15 | igarape-miri
# City not found. Skipping...
# Processing Record 13 of Set 15 | lillehammer
# Processing Record 14 of Set 15 | faya
# Processing Record 15 of Set 15 | matay
# Processing Record 16 of Set 15 | talant
# Processing Record 17 of Set 15 | dawson creek
# Processing Record 18 of Set 15 | deputatskiy
# Processing Record 19 of Set 15 | presidencia roque saenz pena
# Processing Record 20 of Set 15 | albanel
# Processing Record 21 of Set 15 | phultala
# Processing Record 22 of Set 15 | huilong
# Processing Record 23 of Set 15 | pamanukan
# Processing Record 24 of Set 15 | soyo
# Processing Record 25 of Set 15 | nalut
# Processing Record 26 of Set 15 | izhma
# Processing Record 27 of Set 15 | jingdezhen
# Processing Record 28 of Set 15 | delray beach
# Processing Record 29 of Set 15 | ilebo
# Processing Record 30 of Set 15 | funadhoo
# Processing Record 31 of Set 15 | omboue
# Processing Record 32 of Set 15 | agadir
# Processing Record 33 of Set 15 | santa ines
# Processing Record 34 of Set 15 | padang
# Processing Record 35 of Set 15 | grajau
# Processing Record 36 of Set 15 | solnechnyy
# Processing Record 37 of Set 15 | pilar
# Processing Record 38 of Set 15 | baloda
# Processing Record 39 of Set 15 | sauda
# Processing Record 40 of Set 15 | antofagasta
# Processing Record 41 of Set 15 | lemesos
# City not found. Skipping...
# Processing Record 42 of Set 15 | beidao
# Processing Record 43 of Set 15 | mananara
# Processing Record 44 of Set 15 | bakchar
# Processing Record 45 of Set 15 | richards bay
# Processing Record 46 of Set 15 | ternate
# Processing Record 47 of Set 15 | itacoatiara
# Processing Record 48 of Set 15 | honningsvag
# Processing Record 49 of Set 15 | nkpor
# Processing Record 50 of Set 15 | tonj
# Processing Record 1 of Set 16 | warrington
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Ushuaia -54.8000  -68.3000     37.06        87          75        4.61
# 1   Felanitx  39.4696    3.1483     77.13        86          16        7.36
# 2     Hasaki  35.7333  140.8333     90.28        75          22       12.15
# 3      Sitka  57.0531 -135.3300     57.09        82          75       12.66
# 4     Touros  -5.1989  -35.4608     74.30        80           0       15.28
# 5   Hermanus -34.4187   19.2345     52.90        51         100        5.37
# 6  Upernavik  72.7868  -56.1549     39.40        85           6        3.11
# 7   Coquimbo -29.9533  -71.3436     51.53        93           0        4.61
# 8   Xinxiang  35.3089  113.8672     85.46        66           2        1.99
# 9      Bluff -46.6000  168.3333     50.81        69         100        9.57
#
#   Country Current Description
# 0      AR       broken clouds
# 1      ES          few clouds
# 2      JP          few clouds
# 3      US          light rain
# 4      BR           clear sky
# 5      ZA     overcast clouds
# 6      GL           clear sky
# 7      CL           clear sky
# 8      CN           clear sky
# 9      NZ     overcast clouds

# %%
# Reorder columns of DataFrame
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ushuaia      AR -54.8000  -68.3000     37.06        87          75
# 1   Felanitx      ES  39.4696    3.1483     77.13        86          16
# 2     Hasaki      JP  35.7333  140.8333     90.28        75          22
# 3      Sitka      US  57.0531 -135.3300     57.09        82          75
# 4     Touros      BR  -5.1989  -35.4608     74.30        80           0
# 5   Hermanus      ZA -34.4187   19.2345     52.90        51         100
# 6  Upernavik      GL  72.7868  -56.1549     39.40        85           6
# 7   Coquimbo      CL -29.9533  -71.3436     51.53        93           0
# 8   Xinxiang      CN  35.3089  113.8672     85.46        66           2
# 9      Bluff      NZ -46.6000  168.3333     50.81        69         100
#
#    Wind Speed Current Description
# 0        4.61       broken clouds
# 1        7.36          few clouds
# 2       12.15          few clouds
# 3       12.66          light rain
# 4       15.28           clear sky
# 5        5.37     overcast clouds
# 6        3.11           clear sky
# 7        4.61           clear sky
# 8        1.99           clear sky
# 9        9.57     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
